# %%
import pandas as pd
import os
from pathlib import Path

# %%
# get parent directory using pathlib
parent_dir = Path(os.getcwd())

# %%
# remove dollar signs and commas
def clean_numeric_str(curr_str):
    if isinstance(curr_str, str):
        return(curr_str.replace('$', '').replace(',', '').replace('%', ''))
    return(curr_str)

# %%
# rental csv is a kaggle dataset available here
# https://www.kaggle.com/rajacsp/toronto-apartment-price
rental_csv = os.path.join(parent_dir, 'Resources', 'Toronto_apartment_rentals_2018.csv')
rental_df = pd.read_csv(rental_csv, thousands=',')

# clean up currency data types
rental_df['Price'] = rental_df['Price'].apply(clean_numeric_str).astype('float')

# check data types
#rental_df.dtypes

# see header
rental_df.head()
# Out:
#    Bedroom  Bathroom  Den                                            Address  \
# 0        2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 1        1       1.0    1        361 Front St W, Toronto, ON M5V 3R5, Canada
# 2        1       1.0    0             89 McGill Street, Toronto, ON, M5B 0B1
# 3        2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 4        1       1.0    0      80 St Patrick St, Toronto, ON M5T 2X6, Canada
#
#          Lat       Long   Price
# 0  43.581639 -79.648193  2450.0
# 1  43.643051 -79.391643  2150.0
# 2  43.660605 -79.378635  1950.0
# 3  43.641087 -79.381405  2900.0
# 4  43.652487 -79.389622  1800.0

# %%
# 2016 census data by Toronto neighbourhood available in the City of Toronto Open Data Portal
census_csv = os.path.join(parent_dir, 'Resources', 'neighbourhoods-profiles-2016-csv-transposed.csv')
census_df = pd.read_csv(census_csv)

# clean up numeric data types
for column in census_df:
    try:
        census_df[column] = census_df[column].apply(clean_numeric_str).astype('float')
    except:
        continue
        
census_df
# Out:
#                     Neighbourhood  Neighbourhood Number  \
# 0                 City of Toronto                   NaN
# 1                 Agincourt North                 129.0
# 2    Agincourt South-Malvern West                 128.0
# 3                       Alderwood                  20.0
# 4                           Annex                  95.0
# ..                            ...                   ...
# 136                      Wychwood                  94.0
# 137                Yonge-Eglinton                 100.0
# 138                Yonge-St.Clair                  97.0
# 139       York University Heights                  27.0
# 140            Yorkdale-Glen Park                  31.0
#
#        TSNS2020 Designation  Population, 2016  Population, 2011  \
# 0                       NaN         2731571.0         2615060.0
# 1            No Designation           29113.0           30279.0
# 2            No Designation           23757.0           21988.0
# 3            No Designation           12054.0           11904.0
# 4            No Designation           30526.0           29177.0
# ..                      ...               ...               ...
# 136          No Designation           14349.0           13986.0
# 137          No Designation           11817.0           10578.0
# 138          No Designation           12528.0           11652.0
# 139                     NIA           27593.0           27713.0
# 140  Emerging Neighbourhood           14804.0           14687.0
#
#      Population Change 2011-2016  Total private dwellings  \
# 0                            4.5                1179057.0
# 1                           -3.9                   9371.0
# 2                            8.0                   8535.0
# 3                            1.3                   4732.0
# 4                            4.6                  18109.0
# ..                           ...                      ...
# 136                          2.6                   6185.0
# 137                         11.7                   6103.0
# 138                          7.5                   7475.0
# 139                         -0.4                  11051.0
# 140                          0.8                   5847.0
#
#      Private dwellings occupied by usual residents  \
# 0                                        1112929.0
# 1                                           9120.0
# 2                                           8136.0
# 3                                           4616.0
# 4                                          15934.0
# ..                                             ...
# 136                                         5887.0
# 137                                         5676.0
# 138                                         7012.0
# 139                                        10170.0
# 140                                         5344.0
#
#      Population density per square kilometre  Land area in square kilometres  \
# 0                                     4334.0                          630.20
# 1                                     3929.0                            7.41
# 2                                     3034.0                            7.83
# 3                                     2435.0                            4.95
# 4                                    10863.0                            2.81
# ..                                       ...                             ...
# 136                                   8541.0                            1.68
# 137                                   7162.0                            1.65
# 138                                  10708.0                            1.17
# 139                                   2086.0                           13.23
# 140                                   2451.0                            6.04
#
#      ...        External migrants  \
# 0    ...                  59945.0
# 1    ...                    605.0
# 2    ...                    490.0
# 3    ...                     70.0
# 4    ...                    835.0
# ..   ...                      ...
# 136  ...                    225.0
# 137  ...                    325.0
# 138  ...                    265.0
# 139  ...                    680.0
# 140  ...                    140.0
#
#      Total - Mobility status 5 years ago - 25% sample data    Non-movers.1  \
# 0                                            2556120.0           1516110.0
# 1                                              27490.0             18865.0
# 2                                              22325.0             13565.0
# 3                                              11370.0              8235.0
# 4                                              27715.0             12980.0
# ..                                                 ...                 ...
# 136                                            12630.0              7930.0
# 137                                            11230.0              5785.0
# 138                                            11865.0              5660.0
# 139                                            26110.0             14720.0
# 140                                            13420.0              9125.0
#
#        Movers.1      Non-migrants.1      Migrants.1  \
# 0     1040015.0            639060.0        400950.0
# 1        8610.0              5445.0          3170.0
# 2        8775.0              5610.0          3145.0
# 3        3130.0              2200.0           925.0
# 4       14735.0              8340.0          6390.0
# ..          ...                 ...             ...
# 136      4700.0              3355.0          1350.0
# 137      5450.0              3020.0          2425.0
# 138      6195.0              3895.0          2310.0
# 139     11400.0              6435.0          4965.0
# 140      4290.0              2940.0          1345.0
#
#            Internal migrants.1          Intraprovincial migrants.1  \
# 0                     184120.0                            141135.0
# 1                        880.0                               735.0
# 2                        980.0                               760.0
# 3                        680.0                               615.0
# 4                       3930.0                              2630.0
# ..                         ...                                 ...
# 136                      780.0                               570.0
# 137                     1260.0                               970.0
# 138                     1355.0                              1025.0
# 139                     1700.0                              1490.0
# 140                      580.0                               445.0
#
#              Interprovincial migrants.1        External migrants.1
# 0                               42985.0                   216835.0
# 1                                 135.0                     2280.0
# 2                                 220.0                     2170.0
# 3                                  70.0                      245.0
# 4                                1310.0                     2460.0
# ..                                  ...                        ...
# 136                               210.0                      575.0
# 137                               290.0                     1160.0
# 138                               325.0                      955.0
# 139                               195.0                     3285.0
# 140                               135.0                      775.0
#
# [141 rows x 2384 columns]
