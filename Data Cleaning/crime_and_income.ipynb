# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Merge Income data and Crime data

#Call Income data file and dataframe
# %run Cleaned_Income_Data.ipynb
cities_data.head()
# Out:
#                          Cities  Median_Income  Average_Income
# 0               Agincourt North        60162.0         73512.0
# 1  Agincourt South-Malvern West        59013.0         73156.0
# 2                     Alderwood        71585.0         85206.0
# 3                         Annex        57825.0        114333.0
# 4             Banbury-Don Mills        70039.0        115944.0

# %%
#Call Crime data file and dataframe
# %run crime_rate_final_DYK.ipynb
crime_df.head()
# Out:
#                       Hood_ID  Assault Rate  Auto Theft Rate  \
# Cities
# South Parkdale             85        1148.8             91.5
# South Riverdale            70         936.3            143.5
# St.Andrew-Windfields       40         325.6            196.5
# Taylor-Massey              61         777.9             76.5
# Humber Summit              21         950.4           1087.3
#
#                       Break&Enter Rate  Homicide Rate  Robberey Rate  \
# Cities
# South Parkdale                   407.3            4.6          151.0
# South Riverdale                  477.1            0.0          125.6
# St.Andrew-Windfields             466.0            0.0           67.4
# Taylor-Massey                    401.7            6.4           82.9
# Humber Summit                    459.1           24.2          225.5
#
#                       Theft Over Rate  Total Average Rate
# Cities
# South Parkdale                  100.7              317.32
# ...

# %%
#Lets merge two datasets using left , inner and outer join ! (we will decide on one later)
income_crime_merge_left = pd.merge(crime_df, cities_data,  on='Cities' ,how = 'left')
income_crime_merge_inner = pd.merge(crime_df, cities_data,  on='Cities')
income_crime_merge_outer = pd.merge(crime_df, cities_data,  on='Cities' ,how = 'outer')

# save it to CSV file
income_crime_merge_left.to_csv("output_data/city_crime_income_left_140records.csv")
income_crime_merge_inner.to_csv("output_data/city_crime_income_inner_136records.csv")
income_crime_merge_outer.to_csv("output_data/city_crime_income_outer_144records.csv")
#display the merged data
income_crime_merge_left
# Out:
#                          Cities  Hood_ID  Assault Rate  Auto Theft Rate  \
# 0                South Parkdale       85        1148.8             91.5
# 1               South Riverdale       70         936.3            143.5
# 2          St.Andrew-Windfields       40         325.6            196.5
# 3                 Taylor-Massey       61         777.9             76.5
# 4                 Humber Summit       21         950.4           1087.3
# ..                          ...      ...           ...              ...
# 135          Humewood-Cedarvale      106         320.2            111.4
# 136  Islington-City Centre West       14         504.9            391.2
# 137                    Danforth       66         786.3             72.4
# 138                      Rustic       28         593.5            372.2
# 139         Scarborough Village      139        1046.4            107.6
#
#      Break&Enter Rate  Homicide Rate  Robberey Rate  Theft Over Rate  \
# ...
