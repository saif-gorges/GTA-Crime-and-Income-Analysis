# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %run crime_and_income.ipynb

# %%
income_crime_merge_left.head()
# Out:
#                  Cities  Hood_ID  Assault Rate  Auto Theft Rate  \
# 0        South Parkdale       85        1148.8             91.5
# 1       South Riverdale       70         936.3            143.5
# 2  St.Andrew-Windfields       40         325.6            196.5
# 3         Taylor-Massey       61         777.9             76.5
# 4         Humber Summit       21         950.4           1087.3
#
#    Break&Enter Rate  Homicide Rate  Robberey Rate  Theft Over Rate  \
# 0             407.3            4.6          151.0            100.7
# 1             477.1            0.0          125.6             75.3
# 2             466.0            0.0           67.4             33.7
# 3             401.7            6.4           82.9             19.1
# 4             459.1           24.2          225.5            177.2
#
#    Total Average Rate  Median_Income  Average_Income
# 0              317.32        35601.0         46896.0
# 1              292.97        65076.0         83491.0
# 2              181.53        94271.0        189629.0
# 3              227.42        40915.0         51242.0
# 4              487.28        57786.0         68431.0

# %%
# %run starbucks_location_cleaning.ipynb

# %%
starbucks_final.head()
# Out:
#    Hood_ID                      Neighbourhood  Number of Stores
# 0       76                bay street corridor                26
# 1       77  waterfront communities-the island                19
# 2       14         islington-city centre west                 8
# 3       75              church-yonge corridor                 8
# 4       95                              annex                 7

# %%
income_crime_starbucks = pd.merge(income_crime_merge_left, starbucks_final, on='Hood_ID', how='left')
income_crime_starbucks.head()
# Out:
#                  Cities  Hood_ID  Assault Rate  Auto Theft Rate  \
# 0        South Parkdale       85        1148.8             91.5
# 1       South Riverdale       70         936.3            143.5
# 2  St.Andrew-Windfields       40         325.6            196.5
# 3         Taylor-Massey       61         777.9             76.5
# 4         Humber Summit       21         950.4           1087.3
#
#    Break&Enter Rate  Homicide Rate  Robberey Rate  Theft Over Rate  \
# 0             407.3            4.6          151.0            100.7
# 1             477.1            0.0          125.6             75.3
# 2             466.0            0.0           67.4             33.7
# 3             401.7            6.4           82.9             19.1
# 4             459.1           24.2          225.5            177.2
#
#    Total Average Rate  Median_Income  Average_Income         Neighbourhood  \
# 0              317.32        35601.0         46896.0        south parkdale
# 1              292.97        65076.0         83491.0       south riverdale
# 2              181.53        94271.0        189629.0  st.andrew-windfields
# 3              227.42        40915.0         51242.0                   NaN
# 4              487.28        57786.0         68431.0                   NaN
#
#    Number of Stores
# 0               1.0
# 1               1.0
# 2               1.0
# 3               NaN
# 4               NaN

# %%
income_crime_starbucks.drop(['Neighbourhood'], axis='columns', inplace=True)
income_crime_starbucks.head()
# Out:
#                  Cities  Hood_ID  Assault Rate  Auto Theft Rate  \
# 0        South Parkdale       85        1148.8             91.5
# 1       South Riverdale       70         936.3            143.5
# 2  St.Andrew-Windfields       40         325.6            196.5
# 3         Taylor-Massey       61         777.9             76.5
# 4         Humber Summit       21         950.4           1087.3
#
#    Break&Enter Rate  Homicide Rate  Robberey Rate  Theft Over Rate  \
# 0             407.3            4.6          151.0            100.7
# 1             477.1            0.0          125.6             75.3
# 2             466.0            0.0           67.4             33.7
# 3             401.7            6.4           82.9             19.1
# 4             459.1           24.2          225.5            177.2
#
#    Total Average Rate  Median_Income  Average_Income  Number of Stores
# 0              317.32        35601.0         46896.0               1.0
# 1              292.97        65076.0         83491.0               1.0
# 2              181.53        94271.0        189629.0               1.0
# 3              227.42        40915.0         51242.0               NaN
# 4              487.28        57786.0         68431.0               NaN

# %%
income_crime_starbucks.isnull().sum()
# Out:
# Cities                 0
# Hood_ID                0
# Assault Rate           0
# Auto Theft Rate        0
# Break&Enter Rate       0
# Homicide Rate          0
# Robberey Rate          0
# Theft Over Rate        0
# Total Average Rate     0
# Median_Income          4
# Average_Income         4
# Number of Stores      68
# dtype: int64

# %%
income_crime_starbucks['Number of Stores'].fillna(0, inplace=True)
income_crime_starbucks.isnull().sum()
# Out:
# Cities                0
# Hood_ID               0
# Assault Rate          0
# Auto Theft Rate       0
# Break&Enter Rate      0
# Homicide Rate         0
# Robberey Rate         0
# Theft Over Rate       0
# Total Average Rate    0
# Median_Income         4
# Average_Income        4
# Number of Stores      0
# dtype: int64

# %%
income_crime_starbucks
# Out:
#                          Cities  Hood_ID  Assault Rate  Auto Theft Rate  \
# 0                South Parkdale       85        1148.8             91.5
# 1               South Riverdale       70         936.3            143.5
# 2          St.Andrew-Windfields       40         325.6            196.5
# 3                 Taylor-Massey       61         777.9             76.5
# 4                 Humber Summit       21         950.4           1087.3
# ..                          ...      ...           ...              ...
# 135          Humewood-Cedarvale      106         320.2            111.4
# 136  Islington-City Centre West       14         504.9            391.2
# 137                    Danforth       66         786.3             72.4
# 138                      Rustic       28         593.5            372.2
# 139         Scarborough Village      139        1046.4            107.6
#
#      Break&Enter Rate  Homicide Rate  Robberey Rate  Theft Over Rate  \
# 0               407.3            4.6          151.0            100.7
# 1               477.1            0.0          125.6             75.3
# 2               466.0            0.0           67.4             33.7
# 3               401.7            6.4           82.9             19.1
# 4               459.1           24.2          225.5            177.2
# ..                ...            ...            ...              ...
# 135             181.0            0.0           69.6             27.8
# 136             282.0            2.3           79.6             84.2
# 137             413.8            0.0          186.2             41.4
# 138             140.8           10.1           30.2             10.1
# 139             239.2            0.0          167.4             12.0
#
#      Total Average Rate  Median_Income  Average_Income  Number of Stores
# 0                317.32        35601.0         46896.0               1.0
# 1                292.97        65076.0         83491.0               1.0
# 2                181.53        94271.0        189629.0               1.0
# 3                227.42        40915.0         51242.0               0.0
# 4                487.28        57786.0         68431.0               0.0
# ..                  ...            ...             ...               ...
# 135              118.33        57140.0         92623.0               0.0
# 136              224.03        66537.0         89289.0               8.0
# 137              250.02        69640.0         85379.0               1.0
# 138              192.82        43976.0         56844.0               0.0
# 139              262.10        42131.0         62141.0               1.0
#
# [140 rows x 12 columns]

# %%
income_crime_starbucks_df = income_crime_starbucks[income_crime_starbucks['Number of Stores'] != 0.0]
income_crime_starbucks_df
# Out:
#                          Cities  Hood_ID  Assault Rate  Auto Theft Rate  \
# 0                South Parkdale       85        1148.8             91.5
# 1               South Riverdale       70         936.3            143.5
# 2          St.Andrew-Windfields       40         325.6            196.5
# 7         Church-Yonge Corridor       75        2804.7            172.3
# 13                Junction Area       90         591.7            215.8
# ..                          ...      ...           ...              ...
# 131                 The Beaches       63         375.6             92.7
# 133            Thorncliffe Park       55         544.8             61.6
# 136  Islington-City Centre West       14         504.9            391.2
# 137                    Danforth       66         786.3             72.4
# 139         Scarborough Village      139        1046.4            107.6
#
#      Break&Enter Rate  Homicide Rate  Robberey Rate  Theft Over Rate  \
# 0               407.3            4.6          151.0            100.7
# 1               477.1            0.0          125.6             75.3
# 2               466.0            0.0           67.4             33.7
# 7               966.8            3.2          456.3            134.0
# 13              292.4            0.0           97.5             55.7
# ..                ...            ...            ...              ...
# 131             264.3            0.0           74.2             41.7
# 133             127.9            0.0           61.6             23.7
# 136             282.0            2.3           79.6             84.2
# 137             413.8            0.0          186.2             41.4
# 139             239.2            0.0          167.4             12.0
#
#      Total Average Rate  Median_Income  Average_Income  Number of Stores
# 0                317.32        35601.0         46896.0               1.0
# 1                292.97        65076.0         83491.0               1.0
# 2                181.53        94271.0        189629.0               1.0
# 7                756.22        47195.0         65545.0               8.0
# 13               208.85        60789.0         75849.0               1.0
# ..                  ...            ...             ...               ...
# 131              141.42        85028.0        145586.0               4.0
# 133              136.60        40795.0         51739.0               3.0
# 136              224.03        66537.0         89289.0               8.0
# 137              250.02        69640.0         85379.0               1.0
# 139              262.10        42131.0         62141.0               1.0
#
# [72 rows x 12 columns]
