# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
final_df = pd.read_csv("Final_Data.csv")
final_df
# Out:
#      Unnamed: 0               Neighbourhood  Hood_ID  Assault Rate  \
# 0             0              South Parkdale       85        1148.8
# 1             1             South Riverdale       70         936.3
# 2             2        St.Andrew-Windfields       40         325.6
# 3             3               Taylor-Massey       61         777.9
# 4             4               Humber Summit       21         950.4
# ..          ...                         ...      ...           ...
# 135         135          Humewood-Cedarvale      106         320.2
# 136         136  Islington-City Centre West       14         504.9
# 137         137                    Danforth       66         786.3
# 138         138                      Rustic       28         593.5
# 139         139         Scarborough Village      139        1046.4
#
#      Auto Theft Rate  Break&Enter Rate  Homicide Rate  Robberey Rate  \
# 0               91.5             407.3            4.6          151.0
# 1              143.5             477.1            0.0          125.6
# 2              196.5             466.0            0.0           67.4
# 3               76.5             401.7            6.4           82.9
# 4             1087.3             459.1           24.2          225.5
# ..               ...               ...            ...            ...
# 135            111.4             181.0            0.0           69.6
# 136            391.2             282.0            2.3           79.6
# 137             72.4             413.8            0.0          186.2
# 138            372.2             140.8           10.1           30.2
# 139            107.6             239.2            0.0          167.4
#
#      Theft Over Rate  Total Average Rate  Median_Income  Average_Income  \
# 0              100.7              317.32        35601.0         46896.0
# 1               75.3              292.97        65076.0         83491.0
# 2               33.7              181.53        94271.0        189629.0
# 3               19.1              227.42        40915.0         51242.0
# 4              177.2              487.28        57786.0         68431.0
# ..               ...                 ...            ...             ...
# 135             27.8              118.33        57140.0         92623.0
# 136             84.2              224.03        66537.0         89289.0
# 137             41.4              250.02        69640.0         85379.0
# 138             10.1              192.82        43976.0         56844.0
# 139             12.0              262.10        42131.0         62141.0
#
#      Number of Starbucks Stores  Number of Red Lights  Speeding Income Group
# 0                             1                     2        26       25-50K
# 1                             1                     2        20      75-100K
# 2                             1                     1         3     175-200K
# 3                             0                     0         4       50-75K
# 4                             0                     3        23       50-75K
# ..                          ...                   ...       ...          ...
# 135                           0                     0         8      75-100K
# 136                           8                     7        45      75-100K
# 137                           1                     0         6      75-100K
# 138                           0                     1         0       50-75K
# 139                           1                     0        11       50-75K
#
# [140 rows x 16 columns]

# %%
#display income & red lights plot
sorted_df = final_df.sort_values("Average_Income")
df1 = sorted_df.groupby('Income Group', sort=False)['Number of Red Lights'].sum()
df1.plot(kind='bar', x='Income Group', y='Number of Red Lights')
plt.title("Income Range vs. Total Red Lights")
plt.xlabel("Income Range")
plt.ylabel("Total Red Lights")
plt.xticks(rotation=90)
plt.tight_layout
plt.show()

# %%
#display income & speeding plot
df2 = sorted_df.groupby('Income Group', sort = False)['Speeding'].sum()
df2.plot(kind='bar', x='Income Group', y='Speeding Count')
plt.title("Income Range vs. Speeding Count")
plt.xlabel("Income Range")
plt.ylabel("Total Speeding Counts")
plt.xticks(rotation=90)
plt.tight_layout
plt.show()

# %% [markdown]
# # Analysis

# %% [markdown]
# ### Are there more red light cameras in lower income regions?

# %% [markdown]
# From the graphs above, we can see that the majority of red light cameras are implemented in regions with an average income of 50-100K. Comparing this with the total number of speeding tickets per income region we see that the same income region holds the most amount of speeding tickets. We can conclude from this that red light cameras are not necessarly placed in low income regions, but more-so regions where speeding is more commonplace.
