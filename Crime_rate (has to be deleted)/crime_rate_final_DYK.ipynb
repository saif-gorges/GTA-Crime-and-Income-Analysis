# %%
import os
import pandas as pd

# %%
crime_csv = "Neighbourhood_Crime_Rates.csv"
crime_df = pd.read_csv(crime_csv)

# %%
crime_df.head()
# Out:
#    _id  OBJECTID         Neighbourhood  Hood_ID  Population  Assault_2014  \
# 0    1        16        South Parkdale       85       21849           202
# 1    2        17       South Riverdale       70       27876           215
# 2    3        18  St.Andrew-Windfields       40       17812            53
# 3    4        19         Taylor-Massey       61       15683           127
# 4    5        20         Humber Summit       21       12416            76
#
#    Assault_2015  Assault_2016  Assault_2017  Assault_2018  ...  \
# 0           226           231           229           220  ...
# 1           207           236           243           304  ...
# 2            41            48            45            55  ...
# 3            92            97           107           123  ...
# 4            89           118           116           109  ...
#
#    TheftOver_2016  TheftOver_2017  TheftOver_2018  TheftOver_2019  \
# 0               9              10               9              22
# 1              22              27              24              21
# 2               8               7               6               6
# 3               5               2               4               3
# 4              18              18              15              22
#
#    TheftOver_AVG  TheftOver_CHG  TheftOver_Rate_2019   Shape__Area  \
# 0           10.0           1.44                100.7  2.286974e+06
# 1           21.3          -0.13                 75.3  1.096457e+07
# 2            8.5           0.00                 33.7  7.299580e+06
# 3            3.5          -0.25                 19.1  1.062970e+06
# 4           17.3           0.47                177.2  7.966905e+06
#
#    Shape__Length                                           geometry
# 0    10802.83216  {u'type': u'Polygon', u'coordinates': (((-79.4...
# 1    43080.72470  {u'type': u'Polygon', u'coordinates': (((-79.3...
# 2    13025.99746  {u'type': u'Polygon', u'coordinates': (((-79.3...
# 3     5940.70005  {u'type': u'Polygon', u'coordinates': (((-79.2...
# 4    12608.57312  {u'type': u'Polygon', u'coordinates': (((-79.5...
#
# [5 rows x 62 columns]

# %%
crime_df = crime_df.loc[:,["Neighbourhood", "Hood_ID", "Assault_Rate_2019", "AutoTheft_Rate_2019", "BreakandEnter_Rate_2019", "Homicide_Rate_2019", "Robbery_Rate_2019", "TheftOver_Rate_2019"]]

# %%
crime_df
# Out:
#                   Neighbourhood  Hood_ID  Assault_Rate_2019  \
# 0                South Parkdale       85             1148.8
# 1               South Riverdale       70              936.3
# 2          St.Andrew-Windfields       40              325.6
# 3                 Taylor-Massey       61              777.9
# 4                 Humber Summit       21              950.4
# ..                          ...      ...                ...
# 135          Humewood-Cedarvale      106              320.2
# 136  Islington-City Centre West       14              504.9
# 137                    Danforth       66              786.3
# 138                      Rustic       28              593.5
# 139         Scarborough Village      139             1046.4
#
#      AutoTheft_Rate_2019  BreakandEnter_Rate_2019  Homicide_Rate_2019  \
# 0                   91.5                    407.3                 4.6
# 1                  143.5                    477.1                 0.0
# 2                  196.5                    466.0                 0.0
# 3                   76.5                    401.7                 6.4
# 4                 1087.3                    459.1                24.2
# ..                   ...                      ...                 ...
# 135                111.4                    181.0                 0.0
# 136                391.2                    282.0                 2.3
# 137                 72.4                    413.8                 0.0
# 138                372.2                    140.8                10.1
# 139                107.6                    239.2                 0.0
#
#      Robbery_Rate_2019  TheftOver_Rate_2019
# 0                151.0                100.7
# 1                125.6                 75.3
# 2                 67.4                 33.7
# 3                 82.9                 19.1
# 4                225.5                177.2
# ..                 ...                  ...
# 135               69.6                 27.8
# 136               79.6                 84.2
# 137              186.2                 41.4
# 138               30.2                 10.1
# 139              167.4                 12.0
#
# [140 rows x 8 columns]

# %%
crime_df["Total Averate Rate 2019"] = round((crime_df["Assault_Rate_2019"] + crime_df["AutoTheft_Rate_2019"] + crime_df["BreakandEnter_Rate_2019"] +
                                       crime_df["Homicide_Rate_2019"] + crime_df["Robbery_Rate_2019"] + crime_df["TheftOver_Rate_2019"]) / 6, 2)

# %%
crime_df
# Out:
#                   Neighbourhood  Hood_ID  Assault_Rate_2019  \
# 0                South Parkdale       85             1148.8
# 1               South Riverdale       70              936.3
# 2          St.Andrew-Windfields       40              325.6
# 3                 Taylor-Massey       61              777.9
# 4                 Humber Summit       21              950.4
# ..                          ...      ...                ...
# 135          Humewood-Cedarvale      106              320.2
# 136  Islington-City Centre West       14              504.9
# 137                    Danforth       66              786.3
# 138                      Rustic       28              593.5
# 139         Scarborough Village      139             1046.4
#
#      AutoTheft_Rate_2019  BreakandEnter_Rate_2019  Homicide_Rate_2019  \
# 0                   91.5                    407.3                 4.6
# 1                  143.5                    477.1                 0.0
# 2                  196.5                    466.0                 0.0
# 3                   76.5                    401.7                 6.4
# 4                 1087.3                    459.1                24.2
# ..                   ...                      ...                 ...
# 135                111.4                    181.0                 0.0
# 136                391.2                    282.0                 2.3
# 137                 72.4                    413.8                 0.0
# 138                372.2                    140.8                10.1
# 139                107.6                    239.2                 0.0
#
#      Robbery_Rate_2019  TheftOver_Rate_2019  Total Averate Rate 2019
# 0                151.0                100.7                   317.32
# 1                125.6                 75.3                   292.97
# 2                 67.4                 33.7                   181.53
# 3                 82.9                 19.1                   227.42
# 4                225.5                177.2                   487.28
# ..                 ...                  ...                      ...
# 135               69.6                 27.8                   118.33
# 136               79.6                 84.2                   224.03
# 137              186.2                 41.4                   250.02
# 138               30.2                 10.1                   192.82
# 139              167.4                 12.0                   262.10
#
# [140 rows x 9 columns]

# %%
crime_df = crime_df.rename(columns={"Assault_Rate_2019" : "Assault Rate",
                                    "AutoTheft_Rate_2019" : "Auto Theft Rate",
                                    "BreakandEnter_Rate_2019" : "Break&Enter Rate",
                                    "Homicide_Rate_2019" :"Homicide Rate",
                                    "Robbery_Rate_2019" : "Robberey Rate",
                                    "TheftOver_Rate_2019" : "Theft Over Rate",
                                    "Total Averate Rate 2019" : "Total Average Rate"})

# %%
crime_df
# Out:
#                   Neighbourhood  Hood_ID  Assault Rate  Auto Theft Rate  \
# 0                South Parkdale       85        1148.8             91.5
# 1               South Riverdale       70         936.3            143.5
# 2          St.Andrew-Windfields       40         325.6            196.5
# 3                 Taylor-Massey       61         777.9             76.5
# 4                 Humber Summit       21         950.4           1087.3
# ..                          ...      ...           ...              ...
# 135          Humewood-Cedarvale      106         320.2            111.4
# 136  Islington-City Centre West       14         504.9            391.2
# 137                    Danforth       66         786.3             72.4
# 138                      Rustic       28         593.5            372.2
# 139         Scarborough Village      139        1046.4            107.6
#
#      Break&Enter Rate  Homicide Rate  Robberey Rate  Theft Over Rate  \
# 0               407.3            4.6          151.0            100.7
# 1               477.1            0.0          125.6             75.3
# 2               466.0            0.0           67.4             33.7
# 3               401.7            6.4           82.9             19.1
# 4               459.1           24.2          225.5            177.2
# ..                ...            ...            ...              ...
# 135             181.0            0.0           69.6             27.8
# 136             282.0            2.3           79.6             84.2
# 137             413.8            0.0          186.2             41.4
# 138             140.8           10.1           30.2             10.1
# 139             239.2            0.0          167.4             12.0
#
#      Total Average Rate
# 0                317.32
# 1                292.97
# 2                181.53
# 3                227.42
# 4                487.28
# ..                  ...
# 135              118.33
# 136              224.03
# 137              250.02
# 138              192.82
# 139              262.10
#
# [140 rows x 9 columns]

# %%
crime_df = crime_df.set_index('Neighbourhood')

# %%
crime_df
# Out:
#                             Hood_ID  Assault Rate  Auto Theft Rate  \
# Neighbourhood
# South Parkdale                   85        1148.8             91.5
# South Riverdale                  70         936.3            143.5
# St.Andrew-Windfields             40         325.6            196.5
# Taylor-Massey                    61         777.9             76.5
# Humber Summit                    21         950.4           1087.3
# ...                             ...           ...              ...
# Humewood-Cedarvale              106         320.2            111.4
# Islington-City Centre West       14         504.9            391.2
# Danforth                         66         786.3             72.4
# Rustic                           28         593.5            372.2
# Scarborough Village             139        1046.4            107.6
#
#                             Break&Enter Rate  Homicide Rate  Robberey Rate  \
# Neighbourhood
# South Parkdale                         407.3            4.6          151.0
# South Riverdale                        477.1            0.0          125.6
# St.Andrew-Windfields                   466.0            0.0           67.4
# Taylor-Massey                          401.7            6.4           82.9
# Humber Summit                          459.1           24.2          225.5
# ...                                      ...            ...            ...
# Humewood-Cedarvale                     181.0            0.0           69.6
# Islington-City Centre West             282.0            2.3           79.6
# Danforth                               413.8            0.0          186.2
# Rustic                                 140.8           10.1           30.2
# Scarborough Village                    239.2            0.0          167.4
#
#                             Theft Over Rate  Total Average Rate
# Neighbourhood
# South Parkdale                        100.7              317.32
# South Riverdale                        75.3              292.97
# St.Andrew-Windfields                   33.7              181.53
# Taylor-Massey                          19.1              227.42
# Humber Summit                         177.2              487.28
# ...                                     ...                 ...
# Humewood-Cedarvale                     27.8              118.33
# Islington-City Centre West             84.2              224.03
# Danforth                               41.4              250.02
# Rustic                                 10.1              192.82
# Scarborough Village                    12.0              262.10
#
# [140 rows x 8 columns]

# %%
income_df = pd.read_excel('Resources/neighbourhood-income-data-2011.xlsx')
income_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-b4c0fa87d4ff> in <module>
# ----> 1 income_df = pd.read_excel('Resources/neighbourhood-income-data-2011.xlsx')
#       2 income_df.head()
#
# ~\Anaconda3\envs\geo_env\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~\Anaconda3\envs\geo_env\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~\Anaconda3\envs\geo_env\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine)
#     865         self._io = stringify_path(path_or_buffer)
#     866
# --> 867         self._reader = self._engines[engine](self._io)
#     868
#     869     def __fspath__(self):
#
# ~\Anaconda3\envs\geo_env\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      20         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      21         import_optional_dependency("xlrd", extra=err_msg)
# ---> 22         super().__init__(filepath_or_buffer)
#      23
#      24     @property
#
# ~\Anaconda3\envs\geo_env\lib\site-packages\pandas\io\excel\_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# ~\Anaconda3\envs\geo_env\lib\site-packages\pandas\io\excel\_xlrd.py in load_workbook(self, filepath_or_buffer)
#      35             return open_workbook(file_contents=data)
#      36         else:
# ---> 37             return open_workbook(filepath_or_buffer)
#      38
#      39     @property
#
# ~\Anaconda3\envs\geo_env\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Resources/neighbourhood-income-data-2011.xlsx'

# %%
income_df = income_df.loc[(income_df["Category"] == 'Income') & (income_df["Topic"]  == 'Income of households')
& ((income_df["Attribute"] == 'Median household total income $')|(income_df["Attribute"]  == 'Average household total income $'))]
income_df.head()
