# %%
#import dependencies
import pandas as pd 
import matplotlib.pyplot as plt
import geopandas as gpd
import seaborn as sns
import os
import numpy as np
from geopy.geocoders import Nominatim
# Out:
# C:\Users\STEVE.YO\anaconda3\lib\site-packages\geopandas\_compat.py:84: UserWarning: The Shapely GEOS version (3.4.3-CAPI-1.8.3 r4285) is incompatible with the GEOS version PyGEOS was compiled with (3.8.1-CAPI-1.13.3). Conversions between both will be slow.
#   warnings.warn(

# %%
from shapely.geometry import Point, Polygon

# %%
nb = os.path.join('Resources',"Neighbourhoods","Neighbourhoods-Copy1.shp")
regions = gpd.read_file(nb)
regions['neighbourhood'] = regions['FIELD_7'].str.replace(' \(.+\)', '').str.lower()
regions.head()

# %%
regions['geometry']
# Out:
# 0      POLYGON ((-79.43591570873059 43.68015339477487...
# 1      POLYGON ((-79.41095783825973 43.70408282301482...
# 2      POLYGON ((-79.39119482591805 43.68108112277795...
# 3      POLYGON ((-79.50528791818931 43.75987349878096...
# 4      POLYGON ((-79.4396873322608 43.70560981891119,...
#                              ...
# 135    POLYGON ((-79.24549141813627 43.7306038961779,...
# 136    POLYGON ((-79.40401050329621 43.64718829461605...
# 137    POLYGON ((-79.55235701287408 43.70946928110742...
# 138    POLYGON ((-79.51702514555865 43.64611040169457...
# 139    POLYGON ((-79.28857378769889 43.7960690579961,...
# Name: geometry, Length: 140, dtype: object

# %%
#build dataframe
lights_df = pd.read_csv('Resources/Red Light Cameras Data.csv')
lights_df.head()
# Out:
#     _id  INTERSECTION_ID LINEAR_NAME_FULL_1 LINEAR_NAME_FULL_2  ID  \
# 0  4678       13465959.0      Richmond St E      Parliament St   1
# 1  4679       13467993.0  Lake Shore Blvd W            York St   2
# 2  4680       13444656.0      Steeles Ave W       Carpenter Rd   3
# 3  4681       13444138.0      Steeles Ave W          Hilda Ave   4
# 4  4682       13451893.0          Albion Rd     Silverstone Dr   5
#
#             X            Y  LONGITUDE   LATITUDE  OBJECTID  ...  \
# 0  315768.179  4834966.252 -79.364023  43.654559         1  ...
# 1  314411.515  4833508.939 -79.380868  43.641460         2  ...
# 2  309017.922  4850229.154 -79.447589  43.792013         3  ...
# 3  310492.057  4850673.973 -79.429267  43.796007         4  ...
# 4  296738.069  4844782.178 -79.600094  43.742952         5  ...
#
#       ADDITIONAL_INFO  POLICE_DIVISION_1                 WARD_1  WARD_3  \
# 0                 NaN                 51     Toronto Centre(13)     NaN
# 1  WB LAKE SHORE BLVD                 52  Spadina-Fort York(10)     NaN
# 2                 NaN                 32         York Centre(6)     NaN
# 3                 NaN                 32         Willowdale(18)     NaN
# 4                 NaN                 23     Etobicoke North(1)     NaN
#
#   WARD_2 WARD_4                                               NAME  \
# 0    NaN    NaN                    Richmond St E And Parliament St
# 1    NaN    NaN                      Lake Shore Blvd W And York St
# 2    NaN    NaN  Steeles Ave W And Carpenter Rd / Private Acces...
# 3    NaN    NaN                        Steeles Ave W And Hilda Ave
# 4    NaN    NaN                       Albion Rd And Silverstone Dr
#
#                 DISTRICT   RLC               MAIN
# 0  Toronto and East York  6001      RICHMOND ST E
# 1  Toronto and East York  6002  LAKE SHORE BLVD W
# 2             North York  6003      STEELES AVE W
# 3             North York  6004      STEELES AVE W
# 4         Etobicoke York  6005          ALBION RD
#
# [5 rows x 32 columns]

# %%
# Create a set of starbucks locations lat and lng combinations
lng_lats = []

lngs = lights_df['LONGITUDE']
lats = lights_df['LATITUDE']

lng_lats = zip(lngs, lats)

neighbourhood_id = []
neighbourhood_name = []
lats_list = []
lngs_list = []

for lng_lat in lng_lats:
    point = Point(lng_lat[0], lng_lat[1])
    
    for i in np.arange(len(regions)):
        poly = regions.loc[i, 'geometry']
        
        if point.within(poly):
            neighbourhood_id.append(regions.loc[i, 'FIELD_6'])
            neighbourhood_name.append(regions.loc[i, 'FIELD_7'])
            lats_list.append(lng_lat[1])
            lngs_list.append(lng_lat[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-7119129f1d9f> in <module>
#      18         poly = regions.loc[i, 'geometry']
#      19
# ---> 20         if point.within(poly):
#      21             neighbourhood_id.append(regions.loc[i, 'FIELD_6'])
#      22             neighbourhood_name.append(regions.loc[i, 'FIELD_7'])
#
# ~\anaconda3\lib\site-packages\shapely\geometry\base.py in within(self, other)
#     777     def within(self, other):
#     778         """Returns True if geometry is within the other, else False"""
# --> 779         return bool(self.impl['within'](self, other))
#     780
#     781     def equals_exact(self, other, tolerance):
#
# ~\anaconda3\lib\site-packages\shapely\predicates.py in __call__(self, this, other, *args)
#      11     def __call__(self, this, other, *args):
#      12         self._validate(this)
# ---> 13         self._validate(other, stop_prepared=True)
#      14         try:
#      15             return self.fn(this._geom, other._geom, *args)
#
# ~\anaconda3\lib\site-packages\shapely\topology.py in _validate(self, ob, stop_prepared)
#      15
#      16     def _validate(self, ob, stop_prepared=False):
# ---> 17         if ob is None or ob._geom is None:
#      18             raise ValueError("Null geometry supports no operations")
#      19         if stop_prepared and hasattr(ob, 'prepared'):
#
# AttributeError: 'str' object has no attribute '_geom'

# %%
lights_dict = {
    'Lat' : lats_list,
    'Long' : lngs_list,
    'Hood ID' : neighbourhood_id,
    'Neighbourhood' : neighbourhood_name
}

clean_lights = pd.DataFrame(starbucks_dict)

clean_lights
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ad3aa02629a3> in <module>
#       1 lights_dict = {
# ----> 2     'Lat' : lats_list,
#       3     'Long' : lngs_list,
#       4     'Hood ID' : neighbourhood_id,
#       5     'Neighbourhood' : neighbourhood_name
#
# NameError: name 'lats_list' is not defined

# %%
clean_lights['Neighbourhood'].value_counts()
